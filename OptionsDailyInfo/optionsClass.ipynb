# %%
import datetime

import os

import chardet
import loguru
import pyquery
import requests

from Propotion import Propotion

# %%
import fractions
class Propotion:
    def __init__(self, sort, code, name, percent):
        self.Sort = int(sort)
        self.Code = code
        self.Name = name
        self.Percent = fractions.Fraction(percent[:-1])
    def __repr__(self):
        return (
            f'class Propotion {{ '
            f'Sort={self.Sort}, '
            f'Code={self.Code}, '
            f'Name={self.Name}, '
            f'Percent={float(self.Percent):.4f}% '
            f'}}'
        )

# %%
data = {
    "queryType": 2,
    "marketCode": 0,
    "dateaddcnt": "",
    "commodity_id": "TXO",
    "commodity_id2": "",
    "queryDate": "2020/05/19",
    "MarketCode": 0,
    "commodity_idt": "TXO",
    "commodity_id2t": "",
    "commodity_id2t2": ""
}
resp = requests.post('https://www.taifex.com.tw/cht/3/optDailyMarketReport', data = data)

# %%
txt = None
det = chardet.detect(resp.content)
try:
    if det['confidence'] > 0.5:
        if det['encoding'] == 'big-5':
            txt = resp.content.decode('big5')
        else:
            txt = resp.content.decode(det['encoding'])
    else:
        txt = resp.content.decode('utf-8')
except Exception as e:
    loguru.logger.error(e)
# print(txt)

d = pyquery.PyQuery(txt)
trs = list(d('div#printhere table').items())[2]
trs = list(trs('tr').items())[1:]
for tr in trs:
    tds = list(tr('td').items())
    for td in tds:
        print(td.text().strip(), end="    ")
    print()
# Out:
# TXO    202005    7300    Call    -    -    -    -    3570    -    -    0    0    0    0    3440    3670    -    -
# TXO    202005    7300    Put    -    -    -    -    0.1    -    -    2    0    2    7990    -    0.2    366    0.1
# TXO    202005    7400    Call    -    -    -    -    3470    -    -    0    0    0    0    3340    3570    -    -
# TXO    202005    7400    Put    -    -    -    -    0.1    -    -    0    0    0    557    -    0.2    401    0.1
# TXO    202005    7500    Call    -    -    -    -    3370    -    -    0    0    0    0    3240    3470    -    -
# TXO    202005    7500    Put    -    -    -    -    0.1    -    -    0    0    0    699    -    0.2    386    0.1
# TXO    202005    7600    Call    -    -    -    -    3270    -    -    0    0    0    0    3140    3370    -    -
# TXO    202005    7600    Put    0.1    0.2    0.1    0.2    0.1    ▲+0.1    -    0    2    2    457    -    0.2    439    0.1
# ...

# %%
data = {
    "ctl00$ScriptManager1": "ctl00$ContentPlaceHolder1$UpdatePanel1|ctl00$ContentPlaceHolder1$Timer1",
    "ctl00_ScriptManager1_HiddenField": ";;AjaxControlToolkit, Version=1.0.10618.0, Culture=neutral, PublicKeyToken=28f01b0e84b6d53e:zh-TW:43a0de04-5dca-41f9-a426-313ba06240d5:411fea1c:865923e8:e7c87f07:91bd373d:bbfda34c:30a78ec5:3510d9fc;",
    "ctl00$ContentPlaceHolder1$Uc_future_menu1$hifCategory": "",
    "ctl00$ContentPlaceHolder1$Uc_future_menu1$txtSearch": "",
    "ctl00$ContentPlaceHolder1$cbxRefresh": "on",
    "ctl00$ContentPlaceHolder1$ddlFusa_Commodity": "TXO",
    "ctl00$ContentPlaceHolder1$ddlFusa_SelMon": "202005W4",
    "hiddenInputToUpdateATBuffer_CommonToolkitScripts": "1",
    "__EVENTTARGET": "ctl00$ContentPlaceHolder1$Timer1",
    "__EVENTARGUMENT": "",
    "__LASTFOCUS": "",
    "__VIEWSTATE": "/wEPBRI2MzcyNTYyNTU4MjkxNTc1MzNkXyqVXyO+WUMJCLhwzK2+S6pKdtUH7L9ytVGmmkkK8hU=",
    "__VIEWSTATEGENERATOR": "A9C008F5",
    "__ASYNCPOST": "true"
}
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9,zh-TW;q=0.8,zh-CN;q=0.7,zh;q=0.6,ja;q=0.5,ko;q=0.4",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "925",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Cookie": "_ga=GA1.3.1133851905.1589911483; _gid=GA1.3.331304303.1589911483; ASP.NET_SessionId=vf3a0a2jkonyqfeavckqhn2x; BIGipServerPOOL_INFO512AH_TCP_80=1427509420.20480.0000",
    "dnt": "1",
    "Host": "info512ah.taifex.com.tw",
    "Origin": "https://info512ah.taifex.com.tw",
    "Referer": "https://info512ah.taifex.com.tw/Future/OptQuote_Norl.aspx",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36",
    "X-MicrosoftAjax": "Delta=true",
    "X-Requested-With": "XMLHttpRequest"
}
resp = requests.post('https://info512ah.taifex.com.tw/Future/OptQuote_Norl.aspx', data = data)
print(resp)
# Out:
# <Response [200]>

# %%
txt = None
det = chardet.detect(resp.content)
try:
    if det['confidence'] > 0.5:
        if det['encoding'] == 'big-5':
            txt = resp.content.decode('big5')
        else:
            txt = resp.content.decode(det['encoding'])
    else:
        txt = resp.content.decode('utf-8')
except Exception as e:
    loguru.logger.error(e)
# print(txt)

d = pyquery.PyQuery(txt)
d

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3e131367d150> in <module>
# ----> 1 d()
#
# ~/anaconda3/envs/fintech/lib/python3.6/site-packages/pyquery/pyquery.py in __call__(self, *args, **kwargs)
#     291         length = len(args)
#     292         if length == 0:
# --> 293             raise ValueError('You must provide at least a selector')
#     294         if args[0] == '':
#     295             return self._copy([])
#
# ValueError: You must provide at least a selector

# %%
print(d().items().txt())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c1cfbe48f6b9> in <module>
# ----> 1 print(d().items().txt())
#
# ~/anaconda3/envs/fintech/lib/python3.6/site-packages/pyquery/pyquery.py in __call__(self, *args, **kwargs)
#     291         length = len(args)
#     292         if length == 0:
# --> 293             raise ValueError('You must provide at least a selector')
#     294         if args[0] == '':
#     295             return self._copy([])
#
# ValueError: You must provide at least a selector

# %%
resp
# Out:
# <Response [200]>

# %%
for i in resp:
    print(i)
# Out:
# b'1|#||4|3|pageRedirect||%2f|'

# %%
p = requests.get('https://info512ah.taifex.com.tw/Future/chart.aspx?type=5&size=630400&contract=TXOW4050;10300P&CommodityName=%e8%87%ba%e6%8c%87%e6%9c%9f')

# %%
txt = None
det = chardet.detect(p.content)
print(det)
try:
    if det['confidence'] > 0.5:
        if det['encoding'] == 'big-5':
            print("Sdfw")
            txt = p.content.decode('big5')
        else:
            txt = p.content.decode(det['encoding'])
            print("Sdf3")
    else:
        txt = p.content.decode('utf-8')
        print("Sdf2d")
except Exception as e:
#     loguru.logger.error(e)
    print("Sdf")
    pass
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}
# Sdf

# %%
p.content
# Out:
# b'GIF89av\x02\x90\x01\xf7\x00\x00\x05\x05\x05\x15\x15\x15\x0b3<&&&666\x107@\x13:B\x19?G\x1dBJ EM$HP)LS.QX3T\\;[bFFFTTT[[[A`gDciHfmJhnMjqRntUqwWrxYtz_y\x7fgggyyy\x19G\xa3\x1eK\xa5!M\xa6%P\xa8+U\xaa/X\xac3\\\xad8`\xaf<c\xb1Bg\xb3Ej\xb4Kn\xb6Or\xb9Su\xbaVx\xbc[|\xbdd}\x83uu\x9fll\xb9^^\xe2UU\xfe[[\xfejj\xc2aa\xd9||\xdfgg\xfdss\xed\x7f\x7f\xe6zz\xe9ww\xfe\x01\x80\x01\x0b\x85\x0b\x13\x89\x13\x19\x8c\x19"\x91"+\x95+4\x9a48\x9c8C\xa1CK\xa5KT\xa9TZ\xadZd\xb2dk\xb5kw\xbbwz\xbdzg\x80\x85i\x81\x87l\x84\x89q\x89\x8eu\x8c\x91y\x8f\x94|\x91\x96e\x83\xc1h\x86\xc3m\x8a\xc4r\x8e\xc6u\x91\xc8z\x94\xc9\xdf??\xdfAA\xe0CC\xe1JJ\xe2QQ\xe3^^\xfeVV\xfeZZ\xe5dd\xe6jj\xe7qq\xe8uu\xe9||\xfeff\xfexx\x
# ...

# %%
p.content.decode('gbk')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-78e4aa1e6508> in <module>
# ----> 1 p.content.decode('gbk')
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0x90 in position 8: illegal multibyte sequence
